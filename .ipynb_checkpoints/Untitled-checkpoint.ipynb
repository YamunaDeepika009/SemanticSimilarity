# %%
# 1) Install (run once)
# pip install -U sentence-transformers numpy

import time
import numpy as np
from sentence_transformers import SentenceTransformer

# 2) Toy corpus (replace later with a bigger dataset)
with open("sample.txt", "r", encoding="utf-8") as f:
    docs = [line.strip() for line in f if line.strip()]

# 3) Load a pretrained embedding model (good default)
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# 4) Encode documents
doc_emb = model.encode(docs, normalize_embeddings=True)  # (N, D)

def search(query: str, top_k: int = 3):
    # 5) Encode query
    q = model.encode([query], normalize_embeddings=True)[0]  # (D,)

    # 6) Brute-force cosine via dot product (because normalized)
    t0 = time.time()
    scores = doc_emb @ q  # (N,)
    idx = np.argsort(-scores)[:top_k]
    latency_ms = (time.time() - t0) * 1000

    results = [(int(i), float(scores[i]), docs[i]) for i in idx]
    return latency_ms, results

# 7) Test
lat, results = search("What did zara find?", top_k=3)
print(f"Latency: {lat:.2f} ms")
for i, s, d in results:
    print(f"[{i}] score={s:.3f} | {d}")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 33
#      30     return latency_ms, results
#      32 # 7) Test
# ---> 33 lat, results = search("What did zara find?", top_k=3)
#      34 print(f"Latency: {lat:.2f} ms")
#      35 for i, s, d in results:
#
# Cell In[8], line 29, in search(query, top_k)
#      26 idx = np.argsort(-scores)[:top_k]
#      27 latency_ms = (time.time() - t0) * 1000
# ---> 29 results = [(int(i), float(scores[i]), docs[i]) for i in idx]
#      30 return latency_ms, results
#
# IndexError: invalid index to scalar variable.
